# %%
from om import base
from om.data import *
from om.components import *

session = base.Session()

# %%
session.query(TU).filter(TU.name.ilike('fdh%')).all()
# Out:
# [TU (#11287, fdhF)]

# %%
session.query(Gene).filter(Gene.info.ilike('%formate%')).all()
# Out:
# [Gene: (b0823, ybiW) 860173-862606 (-),
#  Gene: (b0824, ybiY) 862611-863511 (-),
#  Gene: (b0902, pflA) 950339-951080 (-),
#  Gene: (b0903, pflB) 951271-953554 (-),
#  Gene: (b0904, focA) 953608-954466 (-),
#  Gene: (b1241, adhE) 1295445-1298121 (-),
#  Gene: (b1474, fdnG) 1547400-1550448 (+),
#  Gene: (b1475, fdnH) 1550460-1551345 (+),
#  Gene: (b1476, fdnI) 1551337-1551991 (+),
#  Gene: (b2492, focB) 2613933-2614782 (+),
#  Gene: (b2713, hydN) 2837577-2838105 (-),
#  Gene: (b2719, hycG) 2843442-2844210 (-),
#  Gene: (b2720, hycF) 2844209-2844752 (-),
#  Gene: (b2731, fhlA) 2854337-2856416 (+),
#  Gene: (b3114, tdcE) 3260123-3262418 (-),
#  Gene: (b3891, fdhE) 4080298-4081228 (-),
#  Gene: (b3892, fdoI) 4081224-4081860 (-),
#  Gene: (b3893, fdoH) 4081856-4082759 (-),
#  Gene: (b3894, fdoG) 4082771-4085822 (-),
#  Gene: (b3895, fdhD) 4086015-4086849 (+),
#  Gene: (b3951, pflD) 4143994-4146292 (+),
#  Gene: (b3952, pflC) 4146257-4147136 (+),
# ...

# %%
session.query(Gene).filter(Gene.name.ilike('fdhF%')).first().data
# Out:
# [Gene: (b4079, fdhF) 4297218-4299366 (-): 67.92 -- RNAseq_Ar3_glycerol_NH4Cl_O2_1_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 26.19 -- RNAseq_Ar3_glycerol_NH4Cl_O2_3_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 27.66 -- RNAseq_delAr1_glycerol_NH4Cl_O2_2_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 24.07 -- RNAseq_delAr1delAr2_glycerol_NH4Cl_O2_1_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 22.51 -- RNAseq_delAr1delAr2_glycerol_NH4Cl_O2_3_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 142.16 -- RNAseq_delAr2_glycerol_NH4Cl_O2_2_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 17.29 -- RNAseq_delta-crp_glycerol_NH4Cl_O2_1_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 18.97 -- RNAseq_delta-crp_glycerol_NH4Cl_O2_3_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 22.83 -- RNAseq_delta-crp_fructose_NH4Cl_O2_2_1.0,
#  Gene: (b4079, fdhF) 4297218-4299366 (-): 20.36 -- RNAseq_delta-crp_glucose_NH4Cl_O2_1_1.0,
# ...
