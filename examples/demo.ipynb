# %%
from om import base, settings
from om.data import *
from om.components import *

from IPython.display import HTML
from matplotlib import pylab as plt
from math import log
import pandas as pd

ome = base.Session()
genome_data = omics_database.genome_data
# %matplotlib inline
# Out:
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
ome.query(DataSet).all()
# Out:
# [ChIPExperiment (#1, ChIPExo-RpoD_wt_fructose_NH4Cl_O2_1_anti-rpod): ChIPExo RpoD 1,
#  ChIPExperiment (#2, ChIPExo-RpoD_wt_fructose_NH4Cl_O2_2_anti-rpod): ChIPExo RpoD 2,
#  ChIPExperiment (#3, ChIPExo-RpoD_wt_fructose_NH4Cl_O2_3_anti-rpod): ChIPExo RpoD 3,
#  ChIPExperiment (#4, ChIPExo-RpoD_wt_glucose_NH4Cl_O2_1_anti-rpod): ChIPExo RpoD 1,
#  ChIPExperiment (#5, ChIPExo-RpoD_wt_glucose_NH4Cl_O2_2_anti-rpod): ChIPExo RpoD 2,
#  ChIPExperiment (#6, ChIPExo-RpoD_wt_glycerol_NH4Cl_O2_1_anti-rpod): ChIPExo RpoD 1,
#  ChIPExperiment (#7, ChIPExo-RpoD_wt_glycerol_NH4Cl_O2_2_anti-rpod): ChIPExo RpoD 2,
#  ChIPExperiment (#8, ChIPExo-RpoD_wt_glycerol_NH4Cl_O2_3_anti-rpod): ChIPExo RpoD 3,
#  ChIPExperiment (#9, ChIPExo-ArcA_ArcA8myc_glucose_NH4Cl_anaerobic_2_anti-myc): ChIPExo ArcA 2,
#  ChIPExperiment (#10, ChIPExo-ArcA_ArcA8myc_glucose_NH4Cl_anaerobic_3_anti-myc): ChIPExo ArcA 3,
#  ChIPExperiment (#11, ChIPExo-Crp_Ar3_glycerol_NH4Cl_O2_1_anti-crp): ChIPExo Crp 1,
# ...

# %%
ome.query(Gene).filter(Gene.name == 'sucA').one()
# Out:
# Gene: (b0726, sucA) 757928-760730 (+)

# %%
ome.query(Gene).filter(Gene.name == 'sucA').one().data
# Out:
# [Gene: (b0726, sucA) 757928-760730 (+): 2036.29 -- RNAseq_wt_glucose_NH4Cl_O2_1_FeCl2,
#  Gene: (b0726, sucA) 757928-760730 (+): 438.39 -- RNAseq_delta-fur_glucose_NH4Cl_O2_1_dpd,
#  Gene: (b0726, sucA) 757928-760730 (+): 581.44 -- RNAseq_wt_glucose_cytosine_O2_1,
#  Gene: (b0726, sucA) 757928-760730 (+): 558.48 -- RNAseq_bw25113_fumarate_NH4Cl_O2_2_thiamine,
#  Gene: (b0726, sucA) 757928-760730 (+): 505.57 -- RNAseq_delAr1delAr2_glycerol_NH4Cl_O2_1,
#  Gene: (b0726, sucA) 757928-760730 (+): 187.37 -- RNAseq_delAr2_glycerol_NH4Cl_O2_3,
#  Gene: (b0726, sucA) 757928-760730 (+): 177.62 -- RNAseq_delAr2_glycerol_NH4Cl_O2_1,
#  Gene: (b0726, sucA) 757928-760730 (+): 679.02 -- RNAseq_Ar3_glycerol_NH4Cl_O2_2,
#  Gene: (b0726, sucA) 757928-760730 (+): 606.66 -- RNAseq_bw25113_glucose_NH4Cl_O2_2_thiamine,
#  Gene: (b0726, sucA) 757928-760730 (+): 903.34 -- RNAseq_wt_glucose_cytidine_O2_1,
#  Gene: (b0726, sucA) 757928-760730 (+):  0.00 -- RNAseq_wt_glycerol_NH4Cl_O2_1,
# ...

# %%
ged = GeneExpressionData
dged = DifferentialGeneExpressionData
cpge = ChIPPeakGeneExpression

# %%
ome.query(ged).filter(and_(ged.gene_name == 'frdC',
                           ged.electron_acceptor == 'anaerobic')).all()
# Out:
# [Gene: (b4152, frdC), Value:  4.63, std: 0.45, Condition: glucose, NH4Cl, anaerobic, Strain: wt, array_experiment,
#  Gene: (b4152, frdC), Value:  3.66, std: 0.66, Condition: glucose, NH4Cl, anaerobic, Strain: delta-arcA, array_experiment,
#  Gene: (b4152, frdC), Value:  2.58, std: 0.06, Condition: glucose, NH4Cl, anaerobic, Strain: delta-arcAfnr, array_experiment,
#  Gene: (b4152, frdC), Value:  2.36, std: 0.09, Condition: glucose, NH4Cl, anaerobic, Strain: delta-fnr, array_experiment,
#  Gene: (b4152, frdC), Value:  5.23, std: 0.28, Condition: glucose, NH4Cl, anaerobic, Strain: delta-narL, array_experiment,
#  Gene: (b4152, frdC), Value:  4.75, std: 0.21, Condition: glucose, NH4Cl, anaerobic, Strain: delta-narLnarP, array_experiment,
#  Gene: (b4152, frdC), Value:  5.11, std: 0.26, Condition: glucose, NH4Cl, anaerobic, Strain: delta-narP, array_experiment]

# %%
ome.query(dged).filter(and_(dged.gene_name == 'frdC')).all()
# Out:
# [Gene: (b4152, frdC), bw25113, fumarate/acetate, NH4Cl, O2, Fold Change:  1.31, FDR:  0.05,
#  Gene: (b4152, frdC), wt/delta-fur, glucose, NH4Cl, O2, Fold Change:  1.08, FDR:  0.09,
#  Gene: (b4152, frdC), delta-fur, glucose, NH4Cl, O2, Fold Change:  1.63, FDR:  0.01,
#  Gene: (b4152, frdC), bw25113, fumarate/glucose, NH4Cl, O2, Fold Change: -2.70, FDR:  0.00,
#  Gene: (b4152, frdC), bw25113, glucose/acetate, NH4Cl, O2, Fold Change: -1.39, FDR:  0.03,
#  Gene: (b4152, frdC), delAr2/wt, glycerol, NH4Cl, O2, Fold Change: -3.47, FDR:  0.00,
#  Gene: (b4152, frdC), delAr1/wt, glycerol, NH4Cl, O2, Fold Change: -1.88, FDR:  0.01,
#  Gene: (b4152, frdC), Ar3/wt, glycerol, NH4Cl, O2, Fold Change: -1.97, FDR:  0.01,
#  Gene: (b4152, frdC), delta-crp, fructose/glycerol, NH4Cl, O2, Fold Change: -1.35, FDR:  0.02,
#  Gene: (b4152, frdC), delta-crp, glycerol/glucose, NH4Cl, O2, Fold Change: -1.51, FDR:  0.02,
# ...

# %%
ome.query(cpge).filter(and_(cpge.gene_name.ilike('rpo%'))).all()
# Out:
# [TF: Crp, Gene: rpoB, b3987, -1.10,  0.17 Condition: glycerol, NH4Cl, O2 Peak: 4187817-4188018 value:5568.00,
#  TF: Crp, Gene: rpoB, b3987, -1.01,  0.17 Condition: glycerol, NH4Cl, O2 Peak: 4187817-4188018 value:5568.00,
#  TF: Crp, Gene: rpoB, b3987, -1.10,  0.13 Condition: glycerol, NH4Cl, O2 Peak: 4187817-4188018 value:5568.00,
#  TF: Crp, Gene: rpoH, b3461, -0.90,  0.22 Condition: glycerol, NH4Cl, O2 Peak: 3598786-3598987 value:9612.90,
#  TF: Crp, Gene: rpoH, b3461, -0.90,  0.22 Condition: glycerol, NH4Cl, O2 Peak: 3598760-3598961 value:8663.10,
#  TF: Crp, Gene: rpoH, b3461, -1.73,  0.03 Condition: glycerol, NH4Cl, O2 Peak: 3598786-3598987 value:9612.90,
#  TF: Crp, Gene: rpoH, b3461, -1.73,  0.03 Condition: glycerol, NH4Cl, O2 Peak: 3598760-3598961 value:8663.10,
#  TF: Crp, Gene: rpoH, b3461, -0.94,  0.20 Condition: glycerol, NH4Cl, O2 Peak: 3598786-3598987 value:9612.90,
# ...
